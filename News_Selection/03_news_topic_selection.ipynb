# %% [markdown]
# ## 뉴스 주요 키워드 추출 및 텍스트 클러스터링
# ---
# * 전체 크롤링한 뉴스 주요 키워드 추출(TF-IDF)
# * 키워드별 텍스트 클러스터링, 넘버링
# * 클러스터링 된 키워드별 문서 건수 확인

# %% [markdown]
# ### 뉴스 토픽 선정
# * 토큰화된 명사 리스트로만 나오는데
# * 아예 주요 토픽을 만들 수 있을지

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/20220827_all.xlsx") # , encoding = "CP949"
df1.head()
# Out:
#     분야                                           타이틀        발행일자  \
# 0  pol  林龋康 "啊贸盒 犁魄厘 祈氢己ˇ" vs 辫辟侥 "跽 力悼扒 魄荤档 弊 葛烙免脚"  2022-08-27
# 1  pol          국민의힘 '마라톤 의총'…"비대위 해체하고 권성동 물러나라" 분출  2022-08-27
# 2  pol         7조6천억원 규모 국산무기 폴란드 간다…K2전차·K-9자주포(종합)  2022-08-27
# 3  pol          국산 '명품무기' 폴란드 간다…K2전차·K-9자주포 1차 수출계약  2022-08-27
# 4  pol         경북 칠곡 간 이준석 "추석 성묘도 정치적 공격…다들 제정신 아냐"  2022-08-27
#
#                                                   링크  \
# 0  https://news.nate.com/view/20220827n02511?mid=...
# 1  https://news.nate.com/view/20220827n10473?mid=...
# 2  https://news.nate.com/view/20220827n08437?mid=...
# 3  https://news.nate.com/view/20220827n00510?mid=...
# 4  https://news.nate.com/view/20220827n08608?mid=...
#
#                                                   본문
# 0  林龋康 惫刮狼塞 厚惑措氓困盔厘捞 26老 惫刮狼塞 惫雀狼盔 楷蛮雀甫 付摹绊 辑匡 咯狼...
# 1  주호영 국민의힘 비상대책위원장이 27일 서울 여의도 국회에서 열린 긴급 의원총회에 ...
# 2  실제 규모 10조원 이상·9월 FA-50 계약…"K-방산 세계적 경쟁력 입증"방사청...
# 3  최소 10조원 수출 첫발·9월 FA-50 계약…"K-방산 세계적 경쟁력 입증"방사청...
# 4   국민의힘 이준석 전 대표가 27일 경북 칠곡군 선영 묘소를 찾았다. 전날 법원이 ...

# %% [markdown]
# ~~가끔 한자나 외국어로 크롤링되는 것~~ 해결

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3772 entries, 0 to 3771
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   분야      3772 non-null   object
#  1   타이틀     3772 non-null   object
#  2   발행일자    3772 non-null   object
#  3   링크      3772 non-null   object
#  4   본문      3772 non-null   object
# dtypes: object(5)
# memory usage: 147.5+ KB

# %%
df1.shape
# Out:
# (3772, 5)

# %%
df1['분야'].unique()
# Out:
# array(['pol', 'eco', 'soc', 'int', 'its'], dtype=object)

# %% [markdown]
# * 28일자 뉴스

# %%
df2 = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/20220828_all.xlsx") # , encoding = "CP949"
df2.head()
# Out:
#     분야                                   타이틀        발행일자  \
# 0  pol        대통령실 비서관 5명 이상 경질할 듯…"7층에 피바람"  2022-08-28
# 1  pol    野 지도부 7명중 6명이 친명…'문재인당'서 '이재명당' 됐다  2022-08-28
# 2  pol  입국 전 코로나 검사,  추석 후 폐지 검토…입국 후 검사는 유지  2022-08-28
# 3  pol      '이기는 이재명' 증명하고, 검찰에 무너지지 않고…대권갈까  2022-08-28
# 4  pol   이재명 "민생·경제 도움될 정책 공통 추진 요청"…영수회담 제안  2022-08-28
#
#                                                   링크  \
# 0  https://news.nate.com/view/20220828n18931?mid=...
# 1  https://news.nate.com/view/20220828n17513?mid=...
# 2  https://news.nate.com/view/20220828n17903?mid=...
# 3  https://news.nate.com/view/20220828n16664?mid=...
# 4  https://news.nate.com/view/20220828n16661?mid=...
#
#                                                   본문
# 0  비위·무능직원 등 중폭이상 개편 추진대통령실이 비서관급 이하 직원들에 대한 중폭 이...
# 1  더불어민주당 최고위원 5명 중 4명이 친명계로 선출되면서, 명실상부한 ‘이재명의 민...
# 2  정부가 항공기 탑승 전 해외 현지에서 받는 코로나 검사 의무를 추석 연휴 이후 해제...
# 3  [대선주자 이재명의 길]강점은 ‘권력 의지’…약점은 ‘사법 리스크’‘무능한 대통령과...
# 4  대표 당선 직후 기자회견 일문일답“최고위원들과 당직 인선 중지 모아 결정”“호남지역...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6933 entries, 0 to 6932
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   분야      6933 non-null   object
#  1   타이틀     6933 non-null   object
#  2   발행일자    6933 non-null   object
#  3   링크      6933 non-null   object
#  4   본문      6933 non-null   object
# dtypes: object(5)
# memory usage: 270.9+ KB

# %%
df2.shape
# Out:
# (6933, 5)

# %%
df2['분야'].unique()
# Out:
# array(['pol', 'eco', 'soc', 'int', 'its'], dtype=object)

# %% [markdown]
# ### 뉴스마다 토픽 선정

# %% [markdown]
# #### 찾아보기
# * [데이콘 뉴스토픽 분류 - 3등](https://dacon.io/competitions/official/235747/codeshare/3054?page=1&dtype=recent)
# * [textrank - 블로그](https://www.dinolabs.ai/288)

# %%
# !pip install konlpy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#      |████████████████████████████████| 19.4 MB 1.2 MB/s
# Collecting JPype1>=0.7.0
#   Downloading JPype1-1.4.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (453 kB)
#      |████████████████████████████████| 453 kB 66.9 MB/s
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (4.9.1)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.7/dist-packages (from konlpy) (1.21.6)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from JPype1>=0.7.0->konlpy) (4.1.1)
# Installing collected packages: JPype1, konlpy
# Successfully installed JPype1-1.4.0 konlpy-0.6.0

# %%
# !pip install tqdm
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (4.64.0)

# %%
import konlpy
from tqdm import tqdm

# %%
## 28일자 뉴스

df = df2.copy()

# %% [markdown]
# * 분야별로 나누기

# %%
df[df['분야'] == 'pol']['분야'].unique()
# Out:
# array(['pol'], dtype=object)

# %%
df_tmp = df[df['분야'] == 'pol']
df_tmp['분야'].unique()
# Out:
# array(['pol'], dtype=object)

# %%
df.isnull().sum(axis = 0)
# Out:
# 분야      0
# 타이틀     0
# 발행일자    0
# 링크      0
# 본문      0
# dtype: int64

# %%
df[df['본문'].isnull()]
# Out:
# Empty DataFrame
# Columns: [분야, 타이틀, 발행일자, 링크, 본문]
# Index: []

# %% [markdown]
# * 본문 내용 없는 경우 -> 속보/이미지만 있는 기사
#   * 토큰화는 타이틀 포함할 것이므로 일단 삭제하지 않는다.
#   * 오히려 속보면 중요한 뉴스일 수 있기 때문

# %% [markdown]
# ### 중복 제거
# * 중복이 많으면 중요한 기사일 수도 있지만 뉴스 제목이 똑같으면 복사한 기사라고 생각

# %%
df.shape
# Out:
# (6933, 5)

# %%
df = df.drop_duplicates(['타이틀'], keep = 'first')
df.shape
# 제목 같은 기사 약 800개
# Out:
# (6367, 5)

# %%
df[df['본문'].isnull()]
# Out:
# Empty DataFrame
# Columns: [분야, 타이틀, 발행일자, 링크, 본문, text50, text15]
# Index: []

# %%
doc = df.copy()
# doc['text50'] = []

# %%
df['text50'] = np.nan
df['text15'] = np.nan

# %%
df.head(1)
# Out:
#     분야                             타이틀        발행일자  \
# 0  pol  대통령실 비서관 5명 이상 경질할 듯…"7층에 피바람"  2022-08-28
#
#                                                   링크  \
# 0  https://news.nate.com/view/20220828n18931?mid=...
#
#                                                   본문  text50  text15
# 0  비위·무능직원 등 중폭이상 개편 추진대통령실이 비서관급 이하 직원들에 대한 중폭 이...     NaN     NaN

# %%
for index, row in df.iterrows():
  if len(str(df['본문'][index])) >= 50:
    df['text50'][index] = str(df['본문'][index])[:50]
  else:
    df['text50'][index] = str(df['본문'][index])

  if len(str(df['본문'][index])) >= 15:
    df['text15'][index] = str(df['본문'][index])[:15]
  else:
    df['text15'][index] = str(df['본문'][index])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df.text15
# Out:
# 0       비위·무능직원 등 중폭이상
# 1       더불어민주당 최고위원 5명
# 2       정부가 항공기 탑승 전 해외
# 3       [대선주자 이재명의 길]강점
# 4       대표 당선 직후 기자회견 일
#              ...
# 6927    [다시 쓰는 이동통신 연대기
# 6928    줄어든 크기·무게로 착용감
# 6929    나노 기술 활용한 의약품 투
# 6930    [머니투데이 조철희 기자]
# 6932    - 채명수 노타 AI 대표-
# Name: text15, Length: 6367, dtype: object

# %%
# df['text50'] = df['본문'] if len(df['본문']) <= 30 else df['본문'][:30]
#elseif(len(df['본문']) >= 50, df['본문'][:50], df['본문'])
df.tail()
# Out:
#        분야                                           타이틀        발행일자  \
# 6927  its  ㊼ "악법도 법이다"…LGT IMT-2000 사업권 반납 [김문기의 아이씨테크]  2022-08-28
# 6928  its     [써보니] "삼성 노캔 무슨 일?"…한국행 비행기서 빛난 '갤버즈2 프로'  2022-08-28
# 6929  its               나노기술 활용 의약품 투자·연구 활발…"성장 잠재력 커"  2022-08-28
# 6930  its       돈 없어 모텔 살던 스타트업 청년 금의환향…'2조원' 상장사 대표 됐다  2022-08-28
# 6932  its                    AI 다운사이징…"전기차 시대 더 각광받을 것"  2022-08-28
#
#                                                      링크  \
# 6927  https://news.nate.com/view/20220828n01856?mid=...
# 6928  https://news.nate.com/view/20220828n01136?mid=...
# 6929  https://news.nate.com/view/20220828n01113?mid=...
# 6930  https://news.nate.com/view/20220828n01059?mid=...
# 6932  https://news.nate.com/view/20220828n00370?mid=...
#
#                                                      본문  \
# 6927  [다시 쓰는 이동통신 연대기] 9부. 3G 삼국정립우리나라가 정보통신강국으로 성장하...
# 6928  줄어든 크기·무게로 착용감 ↑…40% 개선된 ANC 덕에 비행기 내 외부 소음 차단...
# 6929  나노 기술 활용한 의약품 투자·연구 활발…"성장 잠재력 커"[연합뉴스 자료사진] (...
# 6930  [머니투데이 조철희 기자] [편집자주] 머니투데이 지식·학습 콘텐츠 브랜드 키플랫폼...
# 6932  - 채명수 노타 AI 대표- "AI 모델 최대 98% 경량화해줘"- 삼성, LG, ...
#
#                                                  text50           text15
# 6927  [다시 쓰는 이동통신 연대기] 9부. 3G 삼국정립우리나라가 정보통신강국으로 성장하...  [다시 쓰는 이동통신 연대기
# 6928  줄어든 크기·무게로 착용감 ↑…40% 개선된 ANC 덕에 비행기 내 외부 소음 차단...  줄어든 크기·무게로 착용감
# 6929  나노 기술 활용한 의약품 투자·연구 활발…"성장 잠재력 커"[연합뉴스 자료사진] (...  나노 기술 활용한 의약품 투
# 6930  [머니투데이 조철희 기자] [편집자주] 머니투데이 지식·학습 콘텐츠 브랜드 키플랫폼...  [머니투데이 조철희 기자]
# 6932  - 채명수 노타 AI 대표- "AI 모델 최대 98% 경량화해줘"- 삼성, LG, ...  - 채명수 노타 AI 대표-

# %%
df.to_excel("temp_doc.xlsx")

# %% [markdown]
# * 50글자만 잘라서 중복 제거

# %%
df.duplicated(['text50'])
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6927    False
# 6928    False
# 6929    False
# 6930    False
# 6932    False
# Length: 6367, dtype: bool

# %%
# 앞 50글자 중복되는 행

df[(df.duplicated(['text50']) ==True)].shape
# Out:
# (1008, 7)

# %%
df.drop_duplicates(subset = 'text50', keep = 'first').shape

# 5359행 남는다
# Out:
# (5359, 7)

# %%
df = df.drop_duplicates(subset = 'text50', keep = 'first')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5359 entries, 0 to 6932
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   분야      5359 non-null   object
#  1   타이틀     5359 non-null   object
#  2   발행일자    5359 non-null   object
#  3   링크      5359 non-null   object
#  4   본문      5359 non-null   object
#  5   text50  5359 non-null   object
#  6   text15  5359 non-null   object
# dtypes: object(7)
# memory usage: 334.9+ KB

# %% [markdown]
# * 문제
#   * 속보인 경우, 기자 메일만 남아서 중복으로 처리됨

# %%
# doc[(doc['타이틀'].str.contains('[속보]'))]

# 1639 rows

# %% [markdown]
# * ~[속보]이면 남겨두고, 그 외에는 본문 50글자 같으면 중복으로 제거~

# %%
# doc = pd.DataFrame(doc)

# %%
# doc[doc['타이틀'].str.contains('[속보]')]

# %% [markdown]
# ##### 본문 맨 앞 15자 이내에 한국 지역 이름 포함되면 삭제
# * 서울, 경기, 강원, 충청, 경상, 전라, 인천, 경남, 경북, 대구, 울산, 부산, 광주, 전남, 제주, 전북, 대전, 세종, 충남, 충북, 충청북도, 충청남도, 경상남도, 경상북도, 전라북도, 전라남도

# %%
regions = ['연예', '서울', '경기', '강원', '충청', '경상', '전라', '인천', '경남', '경북', '대구', '울산', '부산', '광주', '전남', '제주', '전북', '대전', '세종', '충남', '충북', '충청북도', '충청남도', '경상남도', '경상북도', '전라북도', '전라남도']

# %%
drop_index_list = [] # 지워버릴 index를 담는 리스트
for i, row in df.iterrows():
    # temp_region = row['text15']
    temp_region = row['본문'].split(".")[0]
    for region in regions:
      if region in temp_region: # 만약 명사리스트가 비어 있다면
          drop_index_list.append(i) # 지울 index 추가
          # print(row['text50'])
doc = df.drop(drop_index_list) # 해당 index를 지우기
doc.shape
# Out:
# (2911, 7)

# %% [markdown]
# ### 형태소 분석기
# * ~뉴스 제목으로 분석~
# * 뉴스 원문으로 분석

# %%
df.shape
# Out:
# (5359, 7)

# %%
## 중복 제거한 데이터프레임 doc => df로 카피
doc2 = df.copy()

# %%
from konlpy.tag import Okt

okt = Okt() # 형태소 분석기 객체 생성
noun_list = []
for content in tqdm(df['text50']): 
    nouns = okt.nouns(content) # 명사만 추출하기, 결과값은 명사 리스트
    noun_list.append(nouns)
# Out:
# 100%|██████████| 5359/5359 [00:24<00:00, 216.52it/s]

# %%
df['nouns1'] = noun_list
df.head(3)
# Out:
#     분야                                   타이틀        발행일자  \
# 0  pol        대통령실 비서관 5명 이상 경질할 듯…"7층에 피바람"  2022-08-28
# 1  pol    野 지도부 7명중 6명이 친명…'문재인당'서 '이재명당' 됐다  2022-08-28
# 2  pol  입국 전 코로나 검사,  추석 후 폐지 검토…입국 후 검사는 유지  2022-08-28
#
#                                                   링크  \
# 0  https://news.nate.com/view/20220828n18931?mid=...
# 1  https://news.nate.com/view/20220828n17513?mid=...
# 2  https://news.nate.com/view/20220828n17903?mid=...
#
#                                                   본문  \
# 0  비위·무능직원 등 중폭이상 개편 추진대통령실이 비서관급 이하 직원들에 대한 중폭 이...
# 1  더불어민주당 최고위원 5명 중 4명이 친명계로 선출되면서, 명실상부한 ‘이재명의 민...
# 2  정부가 항공기 탑승 전 해외 현지에서 받는 코로나 검사 의무를 추석 연휴 이후 해제...
#
#                                               text50           text15  \
# 0  비위·무능직원 등 중폭이상 개편 추진대통령실이 비서관급 이하 직원들에 대한 중폭 이...  비위·무능직원 등 중폭이상
# 1  더불어민주당 최고위원 5명 중 4명이 친명계로 선출되면서, 명실상부한 ‘이재명의 민...  더불어민주당 최고위원 5명
# 2  정부가 항공기 탑승 전 해외 현지에서 받는 코로나 검사 의무를 추석 연휴 이후 해제...  정부가 항공기 탑승 전 해외
#
#                                               nouns1
# 0  [비위, 무능, 직원, 등, 중폭, 이상, 개편, 추진, 대통령실, 비서, 관, 이...
# 1  [민주당, 최고, 위원, 명, 중, 명, 친, 계로, 선출, 명실, 상부, 이재명,...
# 2  [정부, 항공기, 탑승, 전, 해외, 현지, 코로나, 검사, 의무, 추석, 연휴, ...

# %%
df[df['본문'].isnull()]
# Out:
# Empty DataFrame
# Columns: [분야, 타이틀, 발행일자, 링크, 본문, text50, text15, nouns1]
# Index: []

# %%
# 명사리스트 비어있는 경우 삭제

drop_index_list = [] # 지워버릴 index를 담는 리스트
for i, row in df.iterrows():
    temp_nouns = row['nouns1']
    if len(temp_nouns) == 0: # 만약 명사리스트가 비어 있다면
        drop_index_list.append(i) # 지울 index 추가
        
df = df.drop(drop_index_list) # 해당 index를 지우기

# index를 지우면 순회시 index 값이 중간중간 비기 때문에 index를 다시 지정
df.index = range(len(df))

# %%
df.shape
# Out:
# (5081, 8)

# %% [markdown]
# ## TF-IDF
# * 뉴스별 키워드 점수
# * 파라미터
#   * min_df = 최소 빈도값(특정 단어 나타나는 "문서"의 수)
#   * min_df보다 작은 DF를 가진 단어들은 제외, 인덱스 부여하지 않음
#   * ngram_range = 음절 단위 n-gram

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# 문서를 명사 집합으로 보고 문서 리스트로 치환 (tfidfVectorizer 인풋 형태를 맞추기 위해)
text = [" ".join(noun) for noun in df['nouns1']]

tfidf_vectorizer = TfidfVectorizer(min_df = 5, ngram_range=(1,3))
tfidf_vectorizer.fit(text)
vector = tfidf_vectorizer.transform(text).toarray()

# %%
text[:10]
# Out:
# ['비위 무능 직원 등 중폭 이상 개편 추진 대통령실 비서 관 이하 직원 대한 중폭 이상 개',
#  '민주당 최고 위원 명 중 명 친 계로 선출 명실 상부 이재명 민주당 이',
#  '정부 항공기 탑승 전 해외 현지 코로나 검사 의무 추석 연휴 이후 해제',
#  '대선 주자 이재명 길 강점 권력 의지 약점 사법 리스크 대통령 국민',
#  '대표 당선 직후 기자회견 일문일답 최고 위원 당직 인선 중지 결정 호남 지역 최고 위',
#  '최고 위원 선거 친 이재명 초 강세 민주당 새 대표 이재명 의원 선출 이 의',
#  '당 당원 모멸 감 언행 추가 징계 결의 법원 결정 격앙 유의',
#  '권성동 수습 의견 고 조경태 윤상현 김태호 의원 등 사퇴 촉',
#  '대통령실 추석 연휴 중폭 비서 관 인사 개편 검토 시민사회 수석 실과 정무',
#  '헌 규 새 비 대위 결론 이준석 체제 유지 추가 가처분 조경태 등 중진 사']

# %%
text[:10]
# Out:
# ['비위 무능 직원 등 중폭 이상 개편 추진 대통령실 비서 관 이하 직원 대한 중폭 이상 개',
#  '민주당 최고 위원 명 중 명 친 계로 선출 명실 상부 이재명 민주당 이',
#  '정부 항공기 탑승 전 해외 현지 코로나 검사 의무 추석 연휴 이후 해제',
#  '대선 주자 이재명 길 강점 권력 의지 약점 사법 리스크 대통령 국민',
#  '대표 당선 직후 기자회견 일문일답 최고 위원 당직 인선 중지 결정 호남 지역 최고 위',
#  '최고 위원 선거 친 이재명 초 강세 민주당 새 대표 이재명 의원 선출 이 의',
#  '당 당원 모멸 감 언행 추가 징계 결의 법원 결정 격앙 유의',
#  '권성동 수습 의견 고 조경태 윤상현 김태호 의원 등 사퇴 촉',
#  '대통령실 추석 연휴 중폭 비서 관 인사 개편 검토 시민사회 수석 실과 정무',
#  '헌 규 새 비 대위 결론 이준석 체제 유지 추가 가처분 조경태 등 중진 사']

# %% [markdown]
# ### TF-IDF 결과로 DBSCAN 클러스터링
# * [DBSCAN 참고](https://pizzathief.oopy.io/dbscan)
#
# ![dbscan para](https://s3.us-west-2.amazonaws.com/secure.notion-static.com/bc797cb7-0491-48bf-9963-40ce4c14b2f5/Untitled.png?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Content-Sha256=UNSIGNED-PAYLOAD&X-Amz-Credential=AKIAT73L2G45EIPT3X45%2F20220828%2Fus-west-2%2Fs3%2Faws4_request&X-Amz-Date=20220828T081916Z&X-Amz-Expires=86400&X-Amz-Signature=ea6ad5c7b0cd723bddf4b1435880b6f1e93bde0adb2951188d1a0222a34d5681&X-Amz-SignedHeaders=host&response-content-disposition=filename%20%3D%22Untitled.png%22&x-id=GetObject)

# %%
from sklearn.cluster import DBSCAN
import numpy as np

vector = np.array(vector) # Normalizer를 이용해 변환된 벡터
model = DBSCAN(eps=0.6,min_samples=5, metric = "cosine")
# 거리 계산 식으로는 Cosine distance를 이용
result = model.fit_predict(vector)
df['result1'] = result

# %%
df.result1.unique()
# Out:
# array([39,  0, -1,  1,  2,  3, 51,  4, 41,  5, 13,  6,  7, 33, 32,  8,  9,
#        10, 11, 12, 14, 20, 15, 16, 17, 47, 18, 19, 21, 31, 22, 23, 37, 24,
#        25, 26, 27, 28, 30, 29, 38, 48, 34, 42, 35, 36, 43, 40, 44, 45, 46,
#        49, 50])

# %%
df.head(3)
# Out:
#     분야                                   타이틀        발행일자  \
# 0  pol        대통령실 비서관 5명 이상 경질할 듯…"7층에 피바람"  2022-08-28
# 1  pol    野 지도부 7명중 6명이 친명…'문재인당'서 '이재명당' 됐다  2022-08-28
# 2  pol  입국 전 코로나 검사,  추석 후 폐지 검토…입국 후 검사는 유지  2022-08-28
#
#                                                   링크  \
# 0  https://news.nate.com/view/20220828n18931?mid=...
# 1  https://news.nate.com/view/20220828n17513?mid=...
# 2  https://news.nate.com/view/20220828n17903?mid=...
#
#                                                   본문  \
# 0  비위·무능직원 등 중폭이상 개편 추진대통령실이 비서관급 이하 직원들에 대한 중폭 이...
# 1  더불어민주당 최고위원 5명 중 4명이 친명계로 선출되면서, 명실상부한 ‘이재명의 민...
# 2  정부가 항공기 탑승 전 해외 현지에서 받는 코로나 검사 의무를 추석 연휴 이후 해제...
#
#                                               text50           text15  \
# 0  비위·무능직원 등 중폭이상 개편 추진대통령실이 비서관급 이하 직원들에 대한 중폭 이...  비위·무능직원 등 중폭이상
# 1  더불어민주당 최고위원 5명 중 4명이 친명계로 선출되면서, 명실상부한 ‘이재명의 민...  더불어민주당 최고위원 5명
# 2  정부가 항공기 탑승 전 해외 현지에서 받는 코로나 검사 의무를 추석 연휴 이후 해제...  정부가 항공기 탑승 전 해외
#
#                                               nouns1  result1
# 0  [비위, 무능, 직원, 등, 중폭, 이상, 개편, 추진, 대통령실, 비서, 관, 이...       39
# 1  [민주당, 최고, 위원, 명, 중, 명, 친, 계로, 선출, 명실, 상부, 이재명,...        0
# 2  [정부, 항공기, 탑승, 전, 해외, 현지, 코로나, 검사, 의무, 추석, 연휴, ...       -1

# %%
df.tail(3)
# Out:
#        분야                                      타이틀        발행일자  \
# 5078  its          나노기술 활용 의약품 투자·연구 활발…"성장 잠재력 커"  2022-08-28
# 5079  its  돈 없어 모텔 살던 스타트업 청년 금의환향…'2조원' 상장사 대표 됐다  2022-08-28
# 5080  its               AI 다운사이징…"전기차 시대 더 각광받을 것"  2022-08-28
#
#                                                      링크  \
# 5078  https://news.nate.com/view/20220828n01113?mid=...
# 5079  https://news.nate.com/view/20220828n01059?mid=...
# 5080  https://news.nate.com/view/20220828n00370?mid=...
#
#                                                      본문  \
# 5078  나노 기술 활용한 의약품 투자·연구 활발…"성장 잠재력 커"[연합뉴스 자료사진] (...
# 5079  [머니투데이 조철희 기자] [편집자주] 머니투데이 지식·학습 콘텐츠 브랜드 키플랫폼...
# 5080  - 채명수 노타 AI 대표- "AI 모델 최대 98% 경량화해줘"- 삼성, LG, ...
#
#                                                  text50           text15  \
# 5078  나노 기술 활용한 의약품 투자·연구 활발…"성장 잠재력 커"[연합뉴스 자료사진] (...  나노 기술 활용한 의약품 투
# 5079  [머니투데이 조철희 기자] [편집자주] 머니투데이 지식·학습 콘텐츠 브랜드 키플랫폼...  [머니투데이 조철희 기자]
# 5080  - 채명수 노타 AI 대표- "AI 모델 최대 98% 경량화해줘"- 삼성, LG, ...  - 채명수 노타 AI 대표-
#
#                                                  nouns1  result1
# 5078  [나노, 기술, 활용, 의약품, 투자, 연구, 활발, 성장, 잠재력, 연합뉴스, 자...        0
# 5079  [머니투데이, 조철희, 기자, 편집, 자주, 머니투데이, 지식, 학습, 콘텐츠, 브...        0
# 5080               [채, 명수, 노타, 대표, 모델, 최대, 경량, 삼성, 카카오]        0

# %% [markdown]
# * 클러스터링 결과 확인

# %%
cluster_idx = {}
cluster_nums = {}
result = list(df['result1'])
for cluster_num in set(df['result1']):
    # -1,0은 노이즈 판별이 났거나 클러스터링이 안된 경우
    if(cluster_num == -1 or cluster_num == 0): 
        continue
    else:
        print("cluster num : {}".format(cluster_num))
       

        temp_df = df[df['result1'] == cluster_num] # cluster num 별로 조회
        num = len(df.index[df['result1'] == cluster_num].to_list())
        for title in temp_df['타이틀']:
            print(title) # 제목으로 살펴보자
        
        # print(df.index[df['result'] == cluster_num].to_list())
        # tmp = [num, df.index[df['result'] == cluster_num].to_list()]
        # tmp = [num] + df.index[df['result'] == cluster_num].to_list()
        
        cluster_idx[cluster_num] = df.index[df['result1'] == cluster_num].to_list()
        # cluster_nums.append(num)
        cluster_nums[cluster_num] = num

        print("docs_num : {}".format(num))

        print()


print(cluster_idx)
# Out:
# cluster num : 1
# 민주당 '이재명號' 출범…與 '권성동 사퇴론' 분출
# 민주당 비대위 체제 종료…'친명 지도부' 출범 공식화
# 與 "당헌·당규 정비해 새 비대위"…반발 목소리도
# 이창용 "연준보다 먼저 금리 인상 종료는 어렵다"
# 차례상 비용 10% 오를 듯…추석 물가 불안한 이유
# 추석 앞두고 친환경 고품질 햅쌀 출하 한창
# 연세로 '차 없는 거리' 폐지 놓고 찬반 논란 가열
# 러-우크라 악연의 역사…침공 6개월 끝나지 않는 전쟁
# docs_num : 8
#
# cluster num : 2
# 한미연합연습 2부 내일 시작…역공·반격작전 연습
# 내일부터 '을지자유의방패' 훈련…한미 전력, 북한 '반격' 포함
# 한미 내일부터 UFS 2부 훈련 돌입….반격작전 시나리오 진행
# 한미연합연습 2부 내일부터 나흘간…軍, 역공 · 반격작전 연습
# 내일부터 한미 연합훈련 2부 진행…北매체 "선전포고나 마찬가지"
# 北매체 "한미 '방패' 간판은 북침 흉계 가리려는 면사포"
# 내일부터 UFS 2부 연습…한미, '수도권 안전 확보' 반격 훈련
# 한·미 'UFS' 2부 연습 29일 시작…北 반격작전 포함돼
# docs_num : 8
#
# cluster num : 3
# 북한 김덕훈 내각총리, 청년절 맞아 청년들 축하
# 북한, 청년절 맞아 각지서 무도회 진행
# 북한, 청년절 맞아 경축행사 진행
# 북한 최룡해, 청년절 맞아 청년들 축하
# 북한, 청년절 맞아 사상 단속…"자본주의와 대결서 승리하자"(종합)
# 국민의힘 "보육원 나온 청년들 위한 정책 마련할 것"
# 북한 "깨끗한 우리 청년들에 자본주의 오염 책동"
# 북한, 청년절 맞아 사상 단속…"자본주의와 대결서 승리하자"
# docs_num : 8
#
# cluster num : 4
# 진중권 "이것은 정당인가, 조폭인가" 원색적 비판…'가처분 결정 반발' 국민의힘 힐난
# "옥외광고의 다양한 세계 엿보길" 서산서 초대전 열려
# '니니코라치우푼타' 구병모, 제16회 김유정문학상
# 국립과천과학관, '아르테미스Ⅰ' 로켓 발사 실황 중계
# 1400만 도민의 축제 '제68회 경기도체육대회 2022 용인' 성황리 폐막
# 캐나다에 한지의 아름다움 알리는 한인 늦깎이 공예 작가
# docs_num : 6
#
# cluster num : 5
# "수해 소상공인에 최대 500만원…추석 때 사적모임 제한 없다"
# 당정 "수해 소상공인에 최대 400만원 지급…성수품값 작년 수준으로"
# 당정 "수해 피해 소상공인, 최대 400만원 지급"
# [속보] 당정, 추석 연휴 고속도로통행료 면제 부활 적극검토
# 당정 "성수품값 작년수준 관리…수해 소상공인에 최대 400만원"
# [속보] 당정 "8월31일까지 합동조사 거쳐 특별재난지역 추가 선포"
# docs_num : 6
#
# cluster num : 6
# 3년 만에 열린 '함안 처녀뱃사공 전국가요제' 성료
# 진주 올빰야시장 임시개장 성료…야간 관광명소 가능성
# 김해시, 경남도민체전 792명 선수단 파견…31개 전종목 출전
# 역대급 실적에도 대·중소 임금 격차는 확대···허울만 좋은 '낙수효과'
# '제61회 경상남도민체육대회' 양산서 개최 [경남브리핑]
# docs_num : 5
#
# cluster num : 7
# 농업에 사활 건 北 "농사 잘 안 되는 것 결코 날씨 탓 아냐"
# 北 평양서 인민반 세대주 배구시합…"승리의 신심"
# 북한 "청신함과 황홀함 담은 신평금강"
# 北 "태권도 모국…세계적 강자 키워내는 사업 총력"
# 北 "세계적 보건위기 종식 때까지 비상 방역전"
# 北 황해남도, 가을걷이·낟알털기 '보여주기 사업' 실시
# 농사일 한창인 북한 청년들…"보람찬 시절 꽃피우리"
# 北 화성지구 1만세대 건설 투입된 청년돌격대여단
# 北 해군절 "조국 바다에 승리 항로 새기는 주체 무력"
# docs_num : 9
#
# cluster num : 8
# 대기업 절반 "올해 임금 인상률, 작년보다 높아"
# "대기업 절반, 올해 임금인상률 지난해보다 높아"
# 전경련 "기업 2곳 중 1곳, 임금인상률 작년보다 높아"
# "국내 대기업 절반가량, 작년보다 올해 임금인상률이 더 높다"
# 올해 타결 평균 임금인상률, 물가상승률보다 낮아
# 기업 10곳 중 5곳 "올해 임금인상률, 작년보다 높다"
# 기업 48.9% "올해 타결된 임금인상률 작년보다 높아"
# "대기업 2곳 중 1곳, 올해 임금인상률 2021년보다 높다"
# 이미 많이 오른 것 같은데…올해 대기업 임금인상률 작년보다 높다
# 대기업 절반 "올해 임금인상률 작년보다 높다"…평균 임금인상률 4.4%↑
# docs_num : 10
#
# cluster num : 9
# 현대엔지니어링 '캐나다 MMR 플랜트' 건설 본격화
# 현대엔지니어링, 캐나다 MMR 실증사업 구매계약
# 현대ENG·美USNC 4세대 초소형모듈원전 프로젝트 맞손
# 현대ENG, 캐나다서 MMR 입지 굳히기
# 현대엔지니어링, 캐나다 '4세대 초소형모듈원전' 플랜트 짓는다
# 현대ENG '초소형모듈원전' 광폭 행보…세계 최초 4세대 MMR 플랜트 건설 임박
# 현대엔지니어링, 북미 MMR 실증 박차 "업계 선두 굳히기"
# 현대엔지니어링, 세계 최초 4세대 초소형모듈원전 건설 목전
# 현대ENG, 캐나다 MMR 실증사업 구매계약…소형원자로 글로벌 경쟁력 확보
# 캐나다 소형원전 설계한 현대ENG, 구매계약도 따냈다
# 'LPGA 첫 승' 맞대결 앞둔 최혜진과 안나린
# CP 여자오픈 3R 마친 뒤 미소짓는 안나린
# CP 여자오픈 3R 공동선두 도약한 최혜진
# 티샷하는 최혜진
# 어프로치 샷하는 안나린
# '공동 선두' 포옹하는 최혜진-안나린
# docs_num : 16
#
# cluster num : 10
# 글로벌 인재 확보 나선 신학철 부회장
# 신학철 LG화학 부회장, 美서 과학기술 인재 직접 찾아나서
# 美서 채용 나선 신학철 LG화학 부회장…"탈탄소 도전에 동참해달라"
# 신학철 LG화학 부회장, 北美서 인재확보 나섰다
# LG화학 신학철 부회장, 美서 글로벌 혁신기술 인재 직접 찾아 나서
# 신학철 LG화학 부회장, 글로벌 혁신기술 인재 찾으러 뉴욕행
# 신학철 LG화학 부회장, 미국서 직접 혁신기술 인재 찾아
# 신학철 LG화학 부회장, 美 혁신 기술 인재 확보 직접 나섰다
# 신학철 LG화학 부회장, 美서 글로벌 혁신기술 인재 직접 찾아 나서
# 신학철 LG화학 부회장, 미국 채용 행사 참여 인재 확보나서
# "인재 찾아라"…LG화학 신학철 부회장, 美뉴욕서 북미 대학 채용설명회
# LG화학 신학철 부회장, 인재 채용 위해 美 직접 찾았다
# 신학철 LG화학 부회장, 美서 글로벌 인재 직접 찾아 나섰다
# 신학철 LG화학 부회장, 美서 혁신기술 인재채용 행사 직접 주관
# LG화학 신학철 부회장, 美서 글로벌 혁신기술 인재 확보 나섰다
# 신학철 LG화학 부회장, 美서 글로벌 혁신기술 인재 직접 찾는다
# docs_num : 16
#
# cluster num : 11
# 대기업 30%, 재생에너지 사용 요구 받아
# 국내 신재생에너지 전력량 부족한데…"글로벌 회사들, 3년 내 RE100 채우라 해"
# 대기업 29% "글로벌 고객사로부터 재생에너지 사용 요구받아"
# 대기업 28.3% "글로벌 고객사로부터 재생에너지 사용 요구"
# "재생에너지 쓰시죠?" 대기업 10곳 중 3곳은 이 질문 들었다
# "대기업 10곳 중 3곳, 수요기업에 재생에너지 사용 요구받아"
# 제조 대기업 10곳 중 3곳 재생에너지 사용 요구 받았다…"정부 인센티브 필요"
# docs_num : 7
#
# cluster num : 12
# 꼬리무는 '수상한 해외송금'…신한, 우리은행 268억 추가 적발
# 수상한 해외 송금 '눈덩이'…은행 무더기 제재 불가피
# '이상 해외 송금'에…은행들 무더기 제재 가능성
# 금리 오르자 예·적금에 뭉칫돈…올해 70조 원 증가
# 금리 오르자…올들어 예·적금에 68조 몰렸다
# 금리 상승에 은행으로 '뭉칫돈'…이달에만 예·적금 7조원 '껑충'
# "시골계신 부모님 어떡하나"…자고나면 사라지는 은행 점포들
# 오늘의 운세 (2022년 8월 29일 月)
# docs_num : 8
#
# cluster num : 13
# '성폭력 폭로' 강민진 "가해자·정의당 그 누구도 사과 안해"
# [기자수첩]KG품에 안긴 쌍용차 새 도약 기대
# 中공업이익 20개월만 마이너스 전환…중국 성장률 전망치 '줄하향'
# 언택트·컨택트 다 보유한 디즈니…2분기 실적 나오자 '긍정평가' ↑
# SK에코플랜트, 1623억 부산 초량1구역 수주…올해 누적액 1조 돌파
# '이재용 사죄 요구' 현수막…강남역에 계속 나부낄 수 있을까
# 故이예람 특검, '부실수사' 의혹 전익수 31일 '재소환' 예정
# 9월 모평 재수생 비율 11년만에 최대 "수능 땐 30% 넘을 듯"
# docs_num : 8
#
# cluster num : 14
# 금감원, 보험사 외화채권 활용해 달러 공급 확대…달러화 강세에 다른 조치
# "원화값 급락, 수출中企에 기회"
# 거스를 수 없는 환율 상승···재정당국 딜레마
# 파월 발언 후폭풍…기로에 선 한미 증시
# 개도국 비즈니스, 불만이 태도가 되지 않아야[박재성의 아웃사이트]
# '재유행 꺾이나' 코로나 신규 확진 8만5295명…1주일 전 대비 2만5613명 감소
# 서울시, 추석 반지하 주택·침수 건물 화재 안전 최우선 살핀다
# [속보] 코로나19 신규 확진 8만5295명…사망 70명·위중증 581명
# docs_num : 8
#
# cluster num : 15
# "교섭 마친 대기업 49%, 임금인상률 지난해보다 높다"
# 대기업 절반, 작년보다 올해 임금인상률 더 높다…재계 "물가 상승 우려"
# 대기업 49% "올해 임금인상률, 작년 인상률보다 높다"
# 기업 48.9% "임금 인상률, 작년보다 높아"…평균 4.4%
# 국내 주요 대기업들 "올해 임금인상률, 작년보다 높다"
# 기업 49%, 임금인상률 작년보다 높아…노동 현안 쟁점 '최저임금 인상'
# docs_num : 6
#
# cluster num : 16
# 모르고 있던 내 보험금, 삼성생명이 찾아드려요
# 삼성생명, 미청구·미지급 보험금 통합조회 구축
# 삼성생명, '보험금 찾기 서비스' 오픈
# 삼성생명, 실손 포함 미청구 보험금 찾아준다
# 삼성생명, 미청구-미지급 보험금까지 찾아준다
# 삼성생명, 보험금 찾기 서비스 개시
# 미래에셋생명, 경영 전반에 ESG 지속가능경영 가속화
# 삼성생명, 청구 가능 보험금과 미지급 보험금 통합 조회 가능한 '보험금 찾기 서비스' 오픈
# 삼성생명, 청구 가능·미지급 보험금 조회 서비스 개시
# 삼성생명, 업계 최초 미청구·미지급까지 조회 가능한 보험금 찾기 서비스 오픈
# 삼성생명, 실손 미청구 보험금 찾아주는 서비스 오픈
# 삼성생명, 보험금 찾기 서비스 오픈
# 삼성생명 "보험금 찾기 서비스 출시"
# 삼성생명, '보험금찾기서비스' 개시…정액뿐 아니라 실손도 조회가능
# docs_num : 14
#
# cluster num : 17
# '아이유 효과' 우리금융 광고 2000만뷰 돌파
# 우리금융그룹, 아이유와 함께한 그룹PR캠페인 영상 2000만 조회수 돌파
# 우리금융, 아이유와 함께한 광고 영상 조회수 2000만 돌파
# 우리금융, 아이유 광고 캠페인 조회수 2000만 돌파
# 우리금융, 아이유와 함께한 광고 캠페인 조회수 2000만 돌파
# [게시판] 우리금융 아이유 출연 광고 조회수 2천만 돌파
# 우리금융, 아이유와 함께한 광고영상 조회수 2000만 돌파
# 우리금융 "아이유와 함께한 광고 캠페인 조회수 2천만 돌파"
# '아이유' 함께 한 우리금융 광고영상 누적 2000만회 조회
# docs_num : 9
#
# cluster num : 18
# '문과생도 이해하기 쉽게'…삼성 출신 전문가, 반도체 입문서 출간
# 덕산하이메탈, 한-미 협력 반도체 패키징 첨단소재 개발 나서
# 용인시, 반도체 산업 육성 위한 발판 마련한다
# 지자체 '황금알 반도체' 기업·산단 유치전
# 용인시, 반도체 산업 육성 위한 종합적인 정책 마련
# 용인특례시, 반도체 산업 육성 위한 종합계획 만든다
# 용인시, 반도체 산업 육성 종합계획 마련 중
# 용인시, 반도체 산업 육성위한 종합계획 만든다
# docs_num : 8
#
# cluster num : 19
# [데이터로 보는 증시]주간 코스닥 기관·외국인·개인 순매수·순매도 상위종목(8월 19일~26일)
# [데이터로 보는 증시]코스피·코스닥 유무상증자 일정
# "기후 위기로 세계 몸살···'이것' 투자하면 돈 번다"[코주부]
# "대표 같아도 중대재해 대응 법인별···반기점검 전부 위탁 불가"
# 'IQ 204' 9세 천재 소년, 내년 과학고 간다
# docs_num : 5
#
# cluster num : 20
# 백두산, 8월 한여름에 폭설…중국은 폭염인데 '제설' 작업이라니
# 中 쓰촨성, 최악 가뭄 이어 폭우 경보…4만6000명 대피
# "中 아직 폭염인데…8월 백두산 천지에 때 이른 폭설" [영상]
# [기후위기현장을 가다] "거대한 미륵불이 온몸을 드러낸 듯했다"
# 바닥 드러낸 '러산 대불' 앞 강
# 받침대 드러난 '러산 대불'
# 백두산에 때 이른 폭설…중국 남방은 39일 연속 고온 경보
# 극심한 가뭄 겪던 중국 쓰촨성에 이번엔 폭우…4만여명 대피
# '3천원 부당이득' 채소상에 1천만원 부과…中 '벌금폭탄' 논란
# 가동 중단된 중국 청두 지하철역 자동발매기
# 말라붙은 중국 쓰촨성 농작물
# 황무지로 변한 중국 쓰촨성 농경지
# 러산 대불 받침대 밑바닥까지 떨어진 수위
# 화려한 야경 사라진 중국 청두 번화가
# '세계 최대' 중국 러산 대불 모습
# 바닥 드러낸 러산 대불 앞 강 모습
# docs_num : 16
#
# cluster num : 21
# SK에코플랜트, 부산초량1구역 가로주택정비사업 수주
# SK에코플랜트, 올해 정비사업 수주 1조 돌파
# 돌아오긴 했는데…불안한 대장주 셀트리온헬스케어, 전망은
# SK에코플랜트, 1623억 규모 부산 '초량1구역' 공사 수주
# SK에코플랜트, '부산 초량1구역' 가로주택정비사업 수주
# SK에코플랜트, 올해 도시정비 누적 수주액 1조 돌파
# SK에코플랜트, 부산 초량1구역 가로주택정비사업 수주
# SK에코플랜트, 올해 도시정비 누적 수주액 1조1000억 원 돌파
# SK에코플랜트, 1623억 규모 부산 '초량1구역 가로주택정비사업' 수주
# SK에코플랜트, 올해 정비사업 수주액 1조원 돌파
# SK에코플랜트, 부산 초량1구역 가로주택사업 수주
# docs_num : 11
#
# cluster num : 22
# "트럼프, 사법방해 혐의 가능성…간첩법보다 형량 두배 높아"
# 트럼프, 사법방해죄로 처벌될까?…최대형량은 징역 20년
# NYT "트럼프, 징역 20년감"  WSJ "마피아 털듯"…압수수색 엇갈린 평가
# 트럼프 덕봤다 이젠 진땀…책 팔려던 사위 쿠슈너의 굴욕
# FBI 선서진술서 공개, 트럼프에 사법방해 혐의 적용 가능성 커져
# 美정보당국 "트럼프, 기밀문서 유출에 따른 안보위험 평가"
# docs_num : 6
#
# cluster num : 23
# 에어부산, 중고생 대상 항공사 진로 특강 실시
# "승무원 되려면~" 에어부산, 부산 중·고등학생 대상 진로특강
# 에어부산, 예비 항공인들 위한 항공사 진로 특강 실시
# 에어부산, 중·고교생에 항공사 진로 특강
# 에어부산 '파일럿 꿈나무' 위한 진로특강 개최
# "파일럿되려면 이렇게 준비하세요"…에어부산, 지역 중·고등학생에게 '항공사 진로특강'
# docs_num : 6
#
# cluster num : 24
# <인사> 환경부
# [인사] 고용노동부
# 오늘의 인사 종합
# [인사] 고용노동부 外
# 8월 29일 인사
# [인사]과학기술정보통신부·행안부 외
# [인사]고용노동부
# [인사] 과학기술정보통신부 외
# <인사> 고용노동부
# [인사] 과학기술정보통신부
# [인사] 환경부
# docs_num : 11
#
# cluster num : 25
# 2022 KT 보야지 투 자라섬
# 3년만에 돌아온 'KT보야지 투 자라섬' 여름밤 달궜다
# [포토] KT, '2022 KT 보야지 투 자라섬' 뮤직 페스티벌
# 입장 기다리는 듀얼버스 관람객들
# KT, 3년만 재개된 뮤직 페스티벌 '2022 KT 보야지 투 자라섬' 성료
# 2만5천명 온 'KT 보야지 투 자라섬' 성료
# 아프리카TV, 대형 뮤직 페스티벌 '랩비트 2022' 단독 생중계
# KT, 2022 보야지 투 자라섬 성료
# KT, 3년만에 돌아온 뮤직 페스티벌 '보야지 투 자라섬' 성료
# KT, 3년 만에 '보야지 투 자라섬' 재개…대표 축제 자리매김
# KT, 뮤직 페스티벌 '2022 KT 보야지 투 자라섬' 성료
# docs_num : 11
#
# cluster num : 26
# "선명하고, 간결하게" 담뱃갑 경고그림·문구 표기 지침 개정
# 아기에게 '꽁초 젖병' 물리는 사진도…담뱃갑 경고그림 연말에 바뀐다
# 담뱃갑 경고그림 표기 지침 개정…'질병명' 강조
# 담뱃갑 경고 그림·문구 바뀐다…'질병' 강조
# 더 세진 담뱃갑 경고그림, 연말 출격…"내일 개정지침 배포"
# '담뱃갑 경고' 12월 말 교체…표기방법 등 매뉴얼 배포
# docs_num : 6
#
# cluster num : 27
# 가을철 '책읽는 서울광장', 내달 2일 금요일 개관
# 엄마아빠가 행복한 '책 읽는 서울광장' 개장…내달 2일부터 매주 금·토·일 열려
# '책읽는 서울광장' 더 넓고 더 길게 9월2일 재개장
# 책 5000권, 엄마·아빠 존…돌아온 '책 읽는 서울광장'
# 책읽는 서울광장, 엄마아빠가 행복한 공간으로…다음달 2일 재개장
# 서울광장이 도서관으로 변한다…책읽는 서울광장 확대
# '책 서울광장' 9월 2일 개장··· 부모 특화존 운영
# 4만5000명 찾은 '책읽는 서울광장' 다시 열린다···운영시간·규모 확대
# 더욱 풍성해진 '책읽는 서울광장'…11월까지 매주 금토일
# 엄마아빠가 행복한 '책 읽는 서울광장' 에어바운스 놀이터 조성
# '책읽는 서울광장' 9월 2일 개장…"엄마아빠도 즐겨요"
# docs_num : 11
#
# cluster num : 28
# 코로나 치료제 정부 지원 올해 집행 0건··· 치료제 국산화 멀어지나
# [주목! e기술] 원숭이두창 치료제, 美 승인 미뤄지는 이유
# [Tech 스토리] '꿈의 전지' 전고체 배터리…2027년 본격 생산
# 아주대 연구팀, 유방암 치료 신기술 개발
# 우리 동네 무더위쉼터, 어디에 몇 곳이 좋을까?
# [블록버스터 톺아보기]경쟁약물에 밀려 입지 좁아진 에이즈 치료제 '트리멕'
# docs_num : 6
#
# cluster num : 29
# [부고] 김복자 씨 별세 外
# [부음] 김복자씨 별세 外
# 8월 29일 궂긴 소식
# [부고] 이준(수원 삼성 블루윙즈 축구단 대표이사)씨 모친상
# [부고]이준 프로축구 수원 삼성 대표이사 모친상
# [부고] 이준(수원 삼성 블루윙즈 축구단 대표이사)씨 모친상 외
# <부고> 이준씨(프로축구 수원 삼성 대표이사) 모친상
# docs_num : 7
#
# cluster num : 30
# 환율 1300원에도 외국인이 담은 주식은?
# [그림이 있는 아침] 움푹 팬 볼, 굳게 다문 입술…그는 평생 붓을 놓지 않았다
# '美 서부 최대 미술관' 안방 차지한 박대성
# 사람에게 받은 상처 사람으로 치유하는 '은혜씨의 포옹'[화제의 책]
# 발튀스 '빨간머리 소녀' 본다…아시아 최초 '신 컬렉션' 전시
# docs_num : 5
#
# cluster num : 31
# 가을맞는 뉴욕증시…이번 주 뉴욕연은 총재 등 줄줄이 연설 [월가월부]
# 샛길로 다니고 바비큐도…불법행위에 국립공원 '몸살'
# 무더위 잦아들고 화창한 날씨…가을 서울숲 만끽
# 가을 문턱에서 강릉 경포 산책
# 경포호수 가을정취 물씬
# 나들이객 가득한 서울숲…"가을 날씨 즐기러"
# 가을 하늘 아래서 서핑
# 파란 하늘…가을이 성큼
# docs_num : 8
#
# cluster num : 32
# "OECD 최저 '이민 불모지' 전락"…한국행 발길 끊은 외국인
# 30년간 전우 추모한 英용사…"나도 한국에 묻어달라"
# 6·25 전사자 수습했던 영국 참전용사, 전우 곁에서 영면
# "에티오피아 참전용사 후손 장학생 선발 재개"···화천군 50명 뽑는다
# 80~90년대 미용계 한국대표 김국애, 수필집 '길을 묻는 사람' 펴내
# docs_num : 5
#
# cluster num : 33
# 특별감찰관, 조속히 임명하길 [이기선 칼럼]
# 서울 종로구 한옥 음식점에서 불…90명 대피
# 서울 종로구 한옥 식당에서 불…손님·직원 90명 대피
# [오늘의 날씨]광주·전남(28일, 일)…쌀쌀한 아침, 일교차 커
# docs_num : 4
#
# cluster num : 34
# [포토] '파란 하늘, 시원한 바람' 나들이하기 좋은 날!
# '선선한 아침' 8월 안 끝났는데 초가을 날씨…왜?
# 따뜻하게 자요…8월의 가을밤, 아침엔 10도 아래 떨어지기도
# "벌써 가을아침"…곳곳 아침기온 '역대 8월 최저' 기록
# 갑자기 왜 이렇게 추워?…'14.4도' 군산은 50년 만에 가장 추운 8월 아침
# [날씨]쌀쌀한 아침에 낮 최고 28℃…"높은 일교차, 건강 유의"
# "성큼 다가온 가을"…경북 상주·청송 '8월 최저기온' 경신
# 오늘의 날씨 - 오전 (2022년 08월 28일)
# "아침 더 쌀쌀"…대구·경북, 한낮에도 25~28도 [오늘날씨]
# docs_num : 9
#
# cluster num : 35
# 담양군, 공직자 대상 '반부패·청렴 교육' 실시
# 함평군, 32억 투입 '1인당 10만 원씩' 제3차 군민재난지원금 지급
# 광주경찰, 추석 명절 앞두고 종합치안활동 전개
# 추석 보름 앞두고 시작된 장성군 '이웃 나눔' 릴레이
# 전북 고창군, 제26회 고창해풍고추축제 개막식 진행
# 제주소방 "화재에 안전한 주택용 소방시설 신청하세요"
# 임택 광주 동구청장 '대한민국 지방자치발전대상' 수상
# 국립광주과학관, 추석맞이 보름달 특별관측 프로그램
# 울주세계산악영화제, 온산 덕신소공원서 '움프의 가을극장' 진행
# docs_num : 9
#
# cluster num : 36
# 부쩍 서늘해진 아침 공기…내일 중부 약한 비
# 전국 곳곳 아침기온 '역대 8월 최저' 기록…쌀쌀한 가을 성큼
# [법정B컷]판결문이 바라본 '檢총장 후보 기밀 유출' 논란
# [Pick] 공기 팔고 '하루 매출 200만 원'…콜롬비아판 봉이 김선달?
# docs_num : 4
#
# cluster num : 37
# 정부, 공공재개발 표류 논란에도 2차 후보지 발표…도심 1만호 주택공급 성공할까
# [엄윤상의 세상만사] 가장 어두운 시간 속 리더십
# "한 두푼도 아닌데…" 대작 영화 참패하고 속편 흥행하는 이유 [연계소문]
# 인사말 하는 사성암 주지 우석스님
# 여름의 끝자락 화엄사 사성암서 '낙락극장' 영화음악회 열려
# [르포] 3년 만에 열린 '한강 야시장' 찾은 시민들…'축제 분위기'
# 시즌2에 힘 주는 OTT…팬덤을 잡아라!
# 케이블TV업계 투자 되네…홈초이스 투자영화 '육사오' 흥행몰이
# docs_num : 8
#
# cluster num : 38
# 올 수능 응시자 3명 중 1명은 'N수생'…26년 만에 최다 전망
# 2023학년도 수능 N수생 응시 26년來 최고 전망
# 'N수생이 수능 응시자 3분의1' 현실화하나
# 수능 N수생 비율 26년 만에 최고 되나…"재수생 30% 이상 예상"
# 올해 수능 응시생 중 졸업생 비중 26년 만에 최고 전망
# docs_num : 5
#
# cluster num : 39
# 대통령실 비서관 5명 이상 경질할 듯…"7층에 피바람"
# 삼성전자 "반도체 유해물질 유출 보도, 사실과 명백히 다르다" 반박
# 생계형 벌급 미납 증가에…노역 대신 '사회봉사' 확대
# 여성에게 흔한 편두통, 극단적 선택 충동까지…
# 늘어나는 성인 실종 신고…뾰족한 수 없어 '무방비'
# 독감 의심 5년만에 최고치…코로나와 '트윈데믹' 비상
# 무연고 사망자 '급증'…2017년 대비 178% 늘었다
# 시도 때도 없이 반복되는 복통 '과민성대장증후군'
# docs_num : 8
#
# cluster num : 40
# 곧 '전어철'인데…새끼 수만마리 목포 앞바다서 폐사, 무슨 일
# '전어 떼 수만만리 폐사해 떠올라'…전남 목포 평화광장 앞 바다
# 목포 평화광장 앞바다서 새끼 전어 수만마리 폐사
# 폐사한 채 발견된 새끼 전어떼
# 폐사한 전어떼 수거하는 어업지도선
# 폐사한 전어떼 떠올리는 환경정화인력
# 목포 평화광장 앞바다서 전어 떼 수만마리 폐사
# docs_num : 7
#
# cluster num : 41
# 경기도교육청, 특수학교 교사 122명 추가 배치
# [모멘트] '민통선 따라 달린다' 뚜르 드 디엠지
# 경기도, 29일 '제2회 사회주택 아카데미' 온라인 진행
# 경기교육청, 특수학교 교사 122명 추가 배치한다
# 경기도 김포서 '인디뮤직 페스티벌' 열린다…10월15~16일
# 경기도, 사회주택 아카데미 개최한다
# 아파트 안방·복도 등에 3차례 불지른 50대 항소심도 '징역 2년'
# 경기도, 29일 '사회주택 아카데미' 개최…사회적주택 공급 활성화 논의
# '경기인디뮤직페스티벌' 10월 15~16일 김포 아라마리나서 개최
# docs_num : 9
#
# cluster num : 42
# 씨름단도 축구단도 '구례 전훈 좋군그래'
# 전남 구례군, 전지훈련 메카로 각광…유치활동 성과
# [곡성소식]죽형 조태일 시인 문학축전…내달 3일 등
# 전남 캠핑관광박람회 '성료'…270팀·1만5천여 명 참여
# docs_num : 4
#
# cluster num : 43
# 교단 누운 채 女교사 촬영한 중학생···"아무도 말리지 않았다"
# 누구도 말리지 않았다…수업 중 교단에 드러누워 女교사 밑에서 촬영한 중학생
# 중학교서 수업 중 교단에 누워 여교사 촬영 '충격'
# "수업 중인데…" 교단에 드러누워 여교사 촬영한 남중생
# [영상] 교사 뒤에서 '찰칵'·수업 중 상의 탈의…도를 넘는 '교권 침해'
# docs_num : 5
#
# cluster num : 44
# "반려견이 물어" vs "만취상태로 무단침입"…민박집서 폭행당해 숨진 반려견
# 깻잎보다 '루테올린'이 14배나 많다고?
# '노안'과 '백내장', 차이점은?
# 눈을 보고 '사망 시점'을 알 수 있다고?
# 혈관청소부, '두부' 효능은?
# docs_num : 5
#
# cluster num : 45
# 연평도 남남서쪽 바다 규모 2.4 지진…"피해 없어"
# 서해 백령도 특산품 메밀 생산량 해마다 줄어든다
# 연평도 앞바다 규모 2.4 지진…"피해 없을 듯"
# 인천 옹진군 연평도 인근 바다 규모 2.4 지진…"피해 없을 듯"
# 인천 옹진 연평도 남남서쪽 바다 규모 2.4 지진…"피해 없을듯"
# docs_num : 5
#
# cluster num : 46
# 韓출산율 최저치 소식에 中 "한국에 과연 미래 있을까" 경계심 유발
# 구조 기다리다 차례로…'종말급 물난리' 1000명 사망 비극 [파키스탄 대홍수]
# "목 조르고 욕설까지"…배우 왕동, '아내 폭행' 동영상 유출 논란
# 10살 '세계 최연소 트랜스젠더 모델' 탄생…소년에서 소녀로 [월드피플+]
# "헉" 택배 열었더니 호랑이 사체가…오배송으로 中 야생동물 밀매 적발
# 의문의 차량 폭발 또 있었다…친러 변절 '배신자' 암살 [포착]
# 中 톱배우, 아내 잔혹 폭행 충격…"살려달라" 동영상 유출
# docs_num : 7
#
# cluster num : 47
# 짝퉁 오명 벗으려는 중국…신시대 브랜드 구축 시동
# "中 아직 폭염인데"…백두산은 때이른 돌풍과 함께 폭설
# 백두산 8월인데 벌써 첫눈이…한때 출입 봉쇄
# [영상]백두산 8월에 폭설…남부는 폭염·가뭄, 中 심상치 않은 이상기후
# 中 남부는 폭염인데, 백두산엔 8월 때 아닌 폭설
# 백두산 때 이른 '폭설', 최근 3년 중 가장 빨라
# docs_num : 6
#
# cluster num : 48
# '미륵사지 미디어아트 페스타' 9월 3일 개막···신비로운 야경에 취한다
# [포토] "슬라바 우크라이니!" 우크라 독립기념일…세계 곳곳 응원 물결
# '아드리아 해의 진주' 크로아티아 두브로브니크 요모조모
# 소년에서 소녀로…세계 최연소 '트랜스젠더' 모델의 나이는?
# [영상] 거칠게 싸우다 '꽈당'…캥거루도 주먹질엔 장사없다
# [특파원시선] 中매체 인용에 엄격한 美언론…선전·선동의 기사가치는
# 대낮에 도둑든 뉴욕 도심 매장…경비원은 멀뚱멀뚱 보고만 있었다
# docs_num : 7
#
# cluster num : 49
# [PWS] 빠른 판단 돋보인 '배고파', 13킬 치킨…GF 우승은 '광동 프릭스'
# [PWS] 막강한 화력 '광동 프릭스'…우승 확정 짓는 3연속 치킨
# [PWS] 2연속 승리 '광동 프릭스'…11킬 '치킨'
# [PWS] 광동프릭스 '이엔드' 완벽한 운영…11킬 '치킨'
# [PWS] 막강한 화력 '다나와 이스포츠', 14킬 '치킨'
# '우승' 보이는 광동, 담원 추격 따돌리고 '1위 굳히기'[PWS]
# docs_num : 6
#
# cluster num : 50
# 이병선 전 카카오 부사장, 제주창조경제혁신센터장 취임
# 코인 거래소 지닥, 이더리움 작업증명(PoW) 하드포크 지원
# 스마트워치 착용해본 사람 54%…필수품 응답은 애플워치가 많아
# 육아 플랫폼 '쑥쑥찰칵', SKT 스타트업 지원 받는다
# 한국청년위원회, 성균관유도회총본부와 NFT 발행
# 신세계아이앤씨, 고용부 주관 '일자리 으뜸기업' 2년 연속 선정
# docs_num : 6
#
# cluster num : 51
# 이동환 고양특례시장, " 1기 신도시 시민들 위해 여야, 중앙정부와 지자체 지혜 모아야 할 시기"
# 재건축 후 2년내 대체주택 양도 땐 비과세
# 기약없는 거래재개···길어지는 개미 '희망고문'
# [클릭, 글로벌 제약·바이오]우울증·루프스 환자 '희소식'
# [써보니] "삼성 노캔 무슨 일?"…한국행 비행기서 빛난 '갤버즈2 프로'
# docs_num : 5
#
# {1: [19, 319, 1130, 1691, 2855, 2870, 4543, 4765], 2: [67, 334, 647, 764, 1120, 1123, 1273, 3395], 3: [97, 98, 99, 100, 125, 981, 1187, 1250], 4: [209, 3325, 3343, 3457, 3747, 4659], 5: [583, 641, 773, 823, 862, 900], 6: [924, 936, 937, 1541, 2943], 7: [1126, 1252, 1253, 1254, 1255, 1256, 1259, 1262, 1263], 8: [1303, 1641, 1797, 2085, 2091, 2124, 2268, 2281, 2293, 2388], 9: [1319, 1415, 1416, 1544, 1582, 1717, 1721, 1754, 1868, 2264, 4720, 4721, 4723, 4850, 4851, 4852], 10: [1328, 1437, 1492, 1511, 1570, 1881, 2030, 2336, 2352, 2358, 2378, 2393, 2394, 2401, 2403, 3748], 11: [1339, 1554, 1865, 1934, 2211, 2218, 4952], 12: [1357, 1370, 1441, 1487, 1571, 1918, 2249, 3149], 13: [815, 1413, 1836, 2010, 2556, 2801, 3788, 3904], 14: [1461, 1470, 1732, 1818, 2533, 3575, 4056, 4242], 15: [1504, 2082, 2338, 2380, 2397, 3964], 16: [1572, 1592, 1823, 1841, 2012, 2013, 2242, 2248, 2554, 2584, 2592, 2602, 2610, 2615], 17: [1591, 1775, 2321, 2578, 2635, 2637, 2641, 2642, 2646], 18: [1667, 1714, 2477, 3021, 3274, 3717, 3805, 3884], 19: [1786, 1822, 2474, 3181, 3406], 20: [1490, 1606, 1802, 3214, 3700, 3701, 4066, 4679, 4779, 4839, 4840, 4841, 4842, 4843, 4844, 4845], 21: [1812, 1824, 2148, 2422, 2435, 2454, 2478, 2547, 2563, 2583, 3771], 22: [1843, 4597, 4600, 4734, 4748, 4889], 23: [1851, 2239, 2409, 3038, 3060, 4254], 24: [2024, 2145, 3050, 3091, 3142, 3318, 3445, 3447, 3802, 4079, 4114], 25: [2041, 2548, 3491, 4273, 4962, 5004, 5020, 5024, 5036, 5069, 5071], 26: [2070, 3340, 3393, 3412, 3943, 3944], 27: [2101, 2303, 2933, 3041, 3613, 3616, 3690, 3711, 4049, 4052, 4062], 28: [2349, 2666, 2709, 2812, 3974, 5073], 29: [2814, 3089, 3132, 3259, 3438, 3444, 3870], 30: [2606, 2803, 2822, 3599, 4466], 31: [1830, 2854, 3344, 3524, 3525, 3634, 3653, 3687], 32: [1299, 2864, 3335, 3582, 4580], 33: [1245, 1419, 2877, 4560], 34: [2915, 2968, 2974, 3408, 3659, 4029, 4256, 4545, 4593], 35: [2973, 2977, 3226, 3247, 3250, 3258, 3302, 3311, 3816], 36: [3008, 3374, 4217, 4622], 37: [1857, 3014, 3510, 4169, 4323, 4518, 4572, 5045], 38: [2837, 3082, 3269, 3286, 4491], 39: [0, 1553, 2859, 3183, 3403, 3535, 4112, 4445], 40: [3351, 3539, 3618, 3629, 3691, 3762, 3766], 41: [545, 3490, 3793, 3896, 3902, 3906, 4192, 4482, 4483], 42: [2934, 3532, 3625, 4266], 43: [3072, 3206, 3310, 3458, 3676], 44: [4252, 4930, 4932, 4934, 4937], 45: [4342, 4435, 4447, 4574, 4576], 46: [4645, 4667, 4713, 4733, 4770, 4782, 4833], 47: [1601, 3576, 4709, 4730, 4776, 4777], 48: [2842, 4610, 4657, 4725, 4803, 4880, 4907], 49: [4916, 4919, 4925, 4929, 4936, 5074], 50: [4920, 5017, 5030, 5048, 5050, 5055], 51: [115, 1351, 1622, 1718, 5077]}

# %%
cluster_nums
# Out:
# {1: 8,
#  2: 8,
#  3: 8,
#  4: 6,
#  5: 6,
#  6: 5,
#  7: 9,
#  8: 10,
#  9: 16,
#  10: 16,
#  11: 7,
#  12: 8,
#  13: 8,
#  14: 8,
#  15: 6,
#  16: 14,
#  17: 9,
#  18: 8,
#  19: 5,
#  20: 16,
#  21: 11,
#  22: 6,
#  23: 6,
#  24: 11,
#  25: 11,
#  26: 6,
#  27: 11,
#  28: 6,
#  29: 7,
#  30: 5,
#  31: 8,
#  32: 5,
#  33: 4,
#  34: 9,
#  35: 9,
#  36: 4,
#  37: 8,
#  38: 5,
#  39: 8,
#  40: 7,
#  41: 9,
#  42: 4,
#  43: 5,
#  44: 5,
#  45: 5,
#  46: 7,
#  47: 6,
#  48: 7,
#  49: 6,
#  50: 6,
#  51: 5}

# %%
## 값으로 정렬해서 위의 5개만 가져오기

## 내림차순 정렬
# sorted(cluster_nums.items(), key = lambda x: x[1])
result_clus = sorted(cluster_nums.items(), key = lambda x:x[1], reverse = True)[:10]
result_clus
# Out:
# [(9, 16),
#  (10, 16),
#  (20, 16),
#  (16, 14),
#  (21, 11),
#  (24, 11),
#  (25, 11),
#  (27, 11),
#  (8, 10),
#  (7, 9)]

# %%
for clus in result_clus:
  print(f"{clus[0]}---------------------------------------")
  temp_df = df[df['result1'] == clus[0]] # cluster num 별로 조회
  print(temp_df['본문'])
# Out:
# 9---------------------------------------
# 1319    美 USNC와 기자재 구매계약발전 설비·냉각 시스템 등 공급현대엔지니어링은 지난 2...
# 1415    지난 26일(현지시간) 캐나다 오타와 USNC 사무실에서 진행된 '캐나다 초크리버 ...
# 1416    - 캐나다 초크리버 MMR 실증사업 구매계약 체결- 기존 MMR 출력 향상 '고출력...
# 1544    미국 전문기업 USNC사와 손잡고캐나다 실증사업 기자재 구매계약   지난 26일(현...
# 1582    미 USNC사와 설비 구매계약최고 수준 안전성, 2026년 준공현대엔지니어링이 캐나...
# 1717    주요 기자재 구매계약 체결 마치고최근 USNC 지분투자금 입금 완료  지난 26일(...
# 1721    美USNC사와 실증사업 기자재 구매계약 체결지난 26일 캐나다 오타와 USNC 사무...
# 1754    캐나다 초크리버 MMR 실증사업 구매계약고출력 다목적 모듈원전 개발 나서현대엔지니어...
# 1868    USNC와 ‘캐나다 초크리버 MMR 실증사업’ 기자재 구매계약발전 설비와 냉각 시스...
# 2264    [머니투데이 유엄식 기자] [캐나다 초크리버 MMR 건설 위한 설비, 냉각 시스템,...
# 4720    (오타와 AP=연합뉴스) 최혜진(왼쪽)과 안나린이 27일(현지시간) 캐나다 온타리오...
# 4721    (오타와 AP=연합뉴스) 안나린이 27일(현지시간) 캐나다 온타리오주 오타와의 오타...
# 4723    (오타와 AP=연합뉴스) 최혜진이 27일(현지시간) 캐나다 온타리오주 오타와의 오타...
# 4850    [오타와=AP/뉴시스] 최혜진이 27일(현지시간) 캐나다 오타와의 오타와헌트앤드골프...
# 4851    [오타와=AP/뉴시스] 안나린이 27일(현지시간) 캐나다 오타와의 오타와헌트앤드골프...
# 4852    [오타와=AP/뉴시스] 최혜진(오른쪽)과 안나린이 27일(현지시간) 캐나다 오타와의...
# Name: 본문, dtype: object
# 10---------------------------------------
# 1328    美서 채용행사 직접 주관신학철 LG화학 부회장(사진)이 미국 현지 채용 행사를 주관...
# 1437    - 신학철 부회장, 美 뉴욕에서 MIT 등 주요 대학 대상- 인재 채용 행사인 직접...
# 1492    LG화학 신학철 부회장이 미국 뉴욕에서 열린 R&D 인재 채용행사 ‘BC(Busin...
# 1511    신학철 LG화학 부회장이 미국 현지 채용 행사를 직접 주관하며 미래 신성장동력 사업...
# 1570    신학철 부회장, 美 뉴욕에서 MIT 등 북미 주요 20여개 대학 대상 인재채용 행사...
# 1881    뉴욕서 MIT 등 북미 주요 대학 대상 인재 채용 행사 'BC 투어' 직접 주관신학...
# 2030    뉴욕서 석·박사 대상 채용행사 진행신학철 LG화학 신학철 부회장이 미국으로 날아가 ...
# 2336    신학철 "과학기술 혁신은 역사적 대전환기의 돌파구"신학철 LG화학 부회장이 지난 2...
# 2352    MIT 등 북미 주요 20여개 대학 대상 인재 채용 행사 'BC(Business &...
# 2358    美뉴욕 MIT 등 북미 주요 20여개 대학 대상[서울=뉴스핌] 김신정 기자 = 신학...
# 2378    기사내용 요약신학철 부회장, 인재 채용 행사인 ‘BC(Business & Campu...
# 2393    [머니투데이 최민경 기자] 신학철 LG화학 부회장이 미국 뉴욕에서 열린 R&D 인재...
# 2394    [이투데이/이다솜 기자]신학철 LG화학 부회장이 미국 뉴욕에서 열린 R&D 인재 채...
# 2401    신학철 LG화학 부회장이 미국 뉴욕에서 열린 R&D 인재 채용행사 'BC(Busin...
# 2403     LG화학 신학철 부회장이 지난 26일 미국 뉴욕에서 열린 R&D 인재 채용행사 ‘...
# 3748         미국 뉴욕에서 열린 R&D 인재 채용행사에 참석한 신학철 LG화학 부회장....
# Name: 본문, dtype: object
# 20---------------------------------------
# 1490    [이투데이/한은수]중국의 네이즌이 틱톡에 올린 백두산 폭설 영상.(출처=트위터)8월...
# 1606    폭염 물러나고 비 내리면서 전력난 해소최근 3개월 동안 극심한 폭염과 가뭄이 이어진...
# 1802    한 중국 네티즌이 틱톡에 올린 영상. /출처=트위터최근 극심한 폭염과 가뭄, 폭우 ...
# 3214    3개월 폭염·가뭄에 러산 대불 받침대 밑바닥 드러내풍부한 수력발전 쓰촨성에 용수 부...
# 3700    (쓰촨성=연합뉴스) 박종국 특파원 = 지난 25일 중국 쓰촨성에 있는 높이 71m의...
# 3701    (쓰촨성=연합뉴스) 박종국 특파원 = 지난 23일 중국 쓰촨성에 있는 높이 71m의...
# 4066    일주일 전 서부 신장지역에도 눈…상하이 고온일수 역대 두번째(선양=연합뉴스) 박종국...
# 4679    최근 심각한 폭염과 가뭄을 겪고 있던 남부 쓰촨성 일부 지역에 폭우가 내려 4만6,...
# 4779    "벌금 남발 말라" 경고한 국무원, 진상조사 착수(선양=연합뉴스) 박종국 특파원 =...
# 4839    (청두=연합뉴스) 박종국 특파원 = 전력 제한으로 중국 쓰촨성 청두 지하철역 자동발...
# 4840    (쓰촨성=연합뉴스) 박종국 특파원 = 25일 중국 쓰촨성 네이장현의 한 밭에 있는 ...
# 4841    (쓰촨성=연합뉴스) 박종국 특파원 = 25일 중국 쓰촨성의 농지가 메마른 황무지로 ...
# 4842    (청두=연합뉴스) 박종국 특파원 = 오랜 폭염과 가뭄으로 중국 쓰촨성 러산 대불 앞...
# 4843    (청두=연합뉴스) 박종국 특파원 = 전력 제한으로 화려한 야경이 사라진 중국 쓰촨성...
# 4844    (청두=연합뉴스) 박종국 특파원 = 높이 71ｍ로 세계 최대 규모인 중국 쓰촨성 러...
# 4845    (청두=연합뉴스) 박종국 특파원 = 중국 쓰촨성 러산 대불 정상 부근에서 바라본 강...
# Name: 본문, dtype: object
# 16---------------------------------------
# 1572    삼성생명이 고객이 스스로 찾아야 했던 보험 혜택을 먼저 알려주는 '보험금 찾기 서비...
# 1592      삼성생명 직원이 보험금을 통합 조회할 수 있는 '보험금 찾기 서비스'를 시연하고...
# 1823    삼성생명은 고객의 치료 이력을 기반으로 청구 가능한 보험금과 미지급된 보험금을 한꺼...
# 1841    - 보험금 예상하기·숨은 보험금 찾기 오픈- 업계 최초 실손 미청구도 조회...앱에...
# 2012    [파이낸셜뉴스]  심성생명이 청구 가능한 보험금과 미지급된 보험금을 통합 조회할 수...
# 2013    삼성생명, 보험금 찾기 서비스 개시삼성생명은 고객의 치료 이력을 기반으로 청구 가능...
# 2242    미래에셋생명 본사 사진/제공 = 미래에셋생명아시아투데이 윤서영 기자 = 미래에셋생명...
# 2248    사진|삼성생명[스포츠서울 | 홍성효기자] 삼성생명이 고객의 치료 이력을 기반으로 청...
# 2554    삼성생명은 28일 가입자가 청구 가능한 보험금과 미지급 보험금을 조회할 수 있는 ‘...
# 2584    삼성생명 보험금 찾기 서비스/제공=삼성생명[데일리한국 박재찬 기자]삼성생명은 고객의...
# 2592    [머니투데이 김세관 기자] 삼성생명은 28일 고객 치료 이력을 기반으로 청구 가능한...
# 2602    삼성생명 모델이 보험금 찾기 서비스를 이용하고 있다.ⓒ삼성생명삼성생명은 고객의 치료...
# 2610    [아시아경제 이창환 기자] 삼성생명은 고객의 치료 이력을 기반으로 청구 가능한 보험...
# 2615    숨은보험금 찾기·보험금 예상 서비스 제공[헤럴드경제=박병국 기자]삼성생명은 고객의 ...
# Name: 본문, dtype: object
# 21---------------------------------------
# 1812    초량1구역 가로주택정비사업 대상지 조감도. SK에코플랜트SK에코플랜트는 부산 초량1...
# 1824     SK에코플랜트가 올해 도시정비사업 누적 수주액 1조원을 돌파했다. SK에코플랜트 ...
# 2148     올초부터 코스닥 대장주를 두고 엎치락 뒤치락해 온 셀트리온헬스케어와 에코프로비엠의...
# 2422    416가구 규모 가로주택정비사업장SK에코플랜트(옛 SK건설)는 부산 초량1구역 가로...
# 2435     부산 초량1구역 가로주택정비사업 조감도. SK에코플랜트 제공 [파이낸셜뉴스]SK에...
# 2454    - 부산 초량1구역 가로주택정비사업 수주- 도시정비사업 6년만에 1조원 돌파[이데일...
# 2478    부산 초량1구역 가로주택정비사업 조감도(SK에코플랜트 제공)(서울=뉴스1) 박승희 ...
# 2547    부산 ‘초량1구역 가로주택정비사업’1623억 원에 수주…고객 중심 설계 제안으로 성...
# 2563     SK에코플랜트가 부산에서 첫 가로주택정비사업을 수주했다. 이로써 올해 도시정비사업...
# 2583    SK에코플랜트가 지난 27일 수주한 부산 초량1구역 가로주택정비사업 조감도. 사진....
# 3771       부산 초량1구역 가로주택정비사업 조감도    [세계비즈=송정은 기자] SK에코...
# Name: 본문, dtype: object
# 24---------------------------------------
# 2024    ◇국장급 전보△대변인 이영석◇과장급 전보△금강홍수통제소장 서해엽ⓒ "젊은 파워, 모...
# 2145    ◇ 국장급 전보▲인천지방노동위원회 위원장 김종철swimming@newspim.com...
# 3050    [이데일리 편집국] ●고용노동부 ◇국장급 전보 △인천지방노동위원회 위원장 김종철▶ ...
# 3091    ◆고용노동부 ◇국장급 전보 △인천지방노동위원회 위원장 김종철  ◆방위사업청 ◇국장급...
# 3142    ⊙ 고용노동부 <전보> ◇국장급 △인천지방노동위원회 위원장 김종철<한겨레 인기기사>...
# 3318    [서울경제]   ◇과학기술정보통신부 <국장급 전보>△국립중앙과학관 전시교육연구단장 ...
# 3445    [서울경제] ◇고용노동부 <국장급 전보>△인천지방노동위원회 위원장 김종철여론독자부 ...
# 3447    [인사] 과학기술정보통신부 외◆과학기술정보통신부 <국장급 전보> △국립중앙과학관 전...
# 3802    ◇ 국장급 전보△ 인천지방노동위원회 위원장 김종철 ⓒ "젊은 파워, 모바일 넘버원 ...
# 4079    ◇국장급 전보(2022년 8월 29일부)▲국립중앙과학관 전시교육연구단장 노경원◇과장...
# 4114    ◇<국장급 전보>(8월 26일자)▲대변인 이영석◇<과장급 전보>(9월 1일자)▲금강...
# Name: 본문, dtype: object
# 25---------------------------------------
# 2041    (서울=연합뉴스) KT가 지난 27일 경기도 가평군 자라섬에서 열린 자사 고객을 위...
# 2548    KT가 자사 고객을 위한 뮤직 페스티벌 ‘2022 KT보야지 투 자라섬(VOYAGE...
# 3491    KT가 뮤직 페스티벌 '2022 KT보야지 투 자라섬(VOYAGE to Jarasu...
# 4273    (서울=뉴스1) = KT가 자사 고객을 위한 뮤직 페스티벌 ‘2022 KT보야지 투...
# 4962         보야지 투 자라섬 관람객이 공연을 즐기고 있다.    KT는 자사 고객을 ...
# 5004    3년만에 재개  지난 27일 경기도 가평군 자라섬에서 열린 '2022 KT 보야지 ...
# 5020    - 9월 3일부터 4일까지- 뮤직 페스티벌 ‘RAPBEAT 2022’ 전세계 동시 ...
# 5024    KT 뮤직 페스티벌 ‘보야지 투 자라섬’이 3년만에 재개됐다. 김범수, 에일리, 다...
# 5036    김범수, 에일리, 다비치 등 공연 성황27일 경기도 가평군 자라섬에서 개최된 '20...
# 5069    보야지 투 자라섬 관람객이 행사장으로 입장하고 있다. 사진=KT[아시아경제 오수연 ...
# 5071    KT, 뮤직 페스티벌 '2022 KT 보야지 투 자라섬' 성료보야지 투 자라섬 관람...
# Name: 본문, dtype: object
# 27---------------------------------------
# 2101    서울광장 도서관, 금·토요일에서 일요일까지 확대서울시청. [사진=서울시]'책읽는 서...
# 2303    [이투데이/김채빈 기자]지난 상반기 열렸던 '책 읽는 서울광장'의 움직이는 책방 모...
# 2933    광장 전체 사용·금요일 추가주말마다 설치되는 야외도서관인 ‘책읽는 서울광장’이 무더...
# 3041    서울시가 올 4~6월 운영한 뒤 휴장했던 ‘책 읽는 서울광장’ 행사를 다음달 2일부...
# 3613    [서울신문]서울시는 도심 속 열린도서관 ‘책읽는 서울광장’이 다음달 2일부터 하반기...
# 3616    다음 달 2일부터하반기 개장 시작도서 5000여권 비치주말 서울광장 전체가 도심 속...
# 3690    마감시간 오후 5시로 1시간 연장다음달 2일 개장하는 ‘책 읽는 서울광장’ 조감도....
# 3711    서울광장’을 찾은 시민들이 잔디 위에 설치된 소파와 매트에 앉아 책을 읽고 있다. ...
# 4049    - 비치 도서 3000→5000권, 전자책 태블릿 대여도- 주말엔 엄마아빠, 아이 ...
# 4052    오세훈 서울시장이 23일 서울광장에 설치된 야외도서관 '책 읽는 서울광장'에서 시민...
# 4062    매주 금·토→금·토·일...오후 5시까지 1시간 연장운영규모 광장 2분의 1→전체....
# Name: 본문, dtype: object
# 8---------------------------------------
# 1303    4.3%만 "작년보다 낮다"국내 대기업 두 곳 중 한 곳꼴로 올해 임금 인상률이 작...
# 1641    국내 대기업 2곳 중 1곳은 올해 임금인상률이 지난해보다 높은 것으로 조사됐습니다....
# 1797    국내 대기업 두 곳 중 한 곳은 올해 임금인상률이 지난해보다 높다는 조사 결과가 나...
# 2085    국내 대기업의 절반가량은 작년보다 올해 임금인상률이 더 높은 것으로 조사됐다.전국경...
# 2091    핵심요약최종 타결 평균 임금인상률 4.4%로 지난해보다 1.2%포인트 상승올해 2분...
# 2124     자료: 전국경제인연합회 [파이낸셜뉴스] 국내 대기업들의 임금 및 단체협약 교섭에서...
# 2268    작년보다 낮다는 응답 4% 불과;임금 교섭 과정 26% “작년보다 어려워”;“경기 ...
# 2281       국내 대기업 약 두 곳 중 한 곳은 올해 임금인상률이 작년보다 높다는 조사 결...
# 2293     올해 국내 대기업들이 임금단체협상 교섭을 진행한 결과, 임금 인상률이 지난해보다 ...
# 2388    [이투데이/이다솜 기자]최종 타결된 임금인상률과 전년 임금인상률 비교(%)(출처=전...
# Name: 본문, dtype: object
# 7---------------------------------------
# 1126    (평양 노동신문=뉴스1) = 북한 조선노동당 기관지 노동신문은 28일 황해남도 안악...
# 1252    (평양 노동신문=뉴스1) = 북한 평양 보통강구역 석암동 배구장에서 지난 25일 인...
# 1253    (평양 노동신문=뉴스1) = 북한 조선노동당 기관지 노동신문이 28일 황해북도 신평...
# 1254    (평양 노동신문=뉴스1) = 북한 조선태권도위원회가 "태권도 모국의 영예를 빛내는 ...
# 1255    (평양 노동신문=뉴스1) = 북한 조선노동당 기관지 노동신문은 28일 세계적인 보건...
# 1256    (평양 노동신문=뉴스1) = 북한 황해남도에서 가을걷이·낟알털기(탈곡) 준비사업을 ...
# 1259    (평양 노동신문=뉴스1) = 북한 조선노동당 기관지 노동신문이 28일 '청춘의 용솟...
# 1262    (평양 노동신문=뉴스1) = 북한 조선노동당 기관지 노동신문이 28일 평양 화성지구...
# 1263    (평양 노동신문=뉴스1) = 북한 조선노동당 기관지 노동신문이 28일 '해군절'을 ...
# Name: 본문, dtype: object

# %% [markdown]
# * 본문 내용이 아예 같은 기사 여러 개 묶여서 클러스터링 결과에 영향 주는 것으로 보임

# %% [markdown]
# * [광주뉴스핌 누구누구 기자] 이런식으로 앞 몇글자 같은 기사들이 묶이는데, text15 정도로 클러스터링 해보기.
# * 연예, 지역 특정 키워드로 묶인 결과에서 거르면 괜찮을 것으로 보임
